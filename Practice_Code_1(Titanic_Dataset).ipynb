# %%
#Importing necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading Csv file using pandas
df=pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#checking if the passenger id column has unique values or not
df["PassengerId"].is_unique
# Out:
# True

# %%
#setting the passengerid column as index column
df.set_index("PassengerId",inplace=True)

# %%
df.sort_index(ascending=True)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Dimension of df
df.shape
# Out:
# (891, 11)

# %%
#Basic info on dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
#Descriptive stats of df
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.sample(2)
# Out:
#              Survived  Pclass                                            Name  \
# PassengerId
# 810                 1       1  Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 160                 0       3                      Sage, Master. Thomas Henry
#
#                 Sex   Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# PassengerId
# 810          female  33.0      1      0    113806  53.10    E8        S
# 160            male   NaN      8      2  CA. 2343  69.55   NaN        S

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df["Sex"]=df["Sex"].astype("category")
df["Sex"]
# Out:
# PassengerId
# 1        male
# 2      female
# 3      female
# 4      female
# 5        male
#         ...
# 887      male
# 888    female
# 889    female
# 890      male
# 891      male
# Name: Sex, Length: 891, dtype: category
# Categories (2, object): ['female', 'male']

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
#checking if there are any null values
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#filling the null values of age column with mean of age column
df["Age"]=df["Age"].fillna(df["Age"].median())
df["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889    28.0
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#dropping the cabin column
df.drop("Cabin",axis=1,inplace=True)

# %%
#dropping the null values
df.dropna(inplace=True)

# %%
#Checking if there are any duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Creating a new column
df["family"]=df["SibSp"]+df["Parch"]
df["family"]
# Out:
# PassengerId
# 1      1
# 2      1
# 3      0
# 4      1
# 5      0
#       ..
# 887    0
# 888    0
# 889    3
# 890    0
# 891    0
# Name: family, Length: 889, dtype: int64

# %%
#Survival count of family
sns.countplot(x="family",hue="Survived",data=df)
plt.title("Survival Count of Family")
# Out:
# Text(0.5, 1.0, 'Survival Count of Family')

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
sns.countplot(x="Survived",data=df)
plt.title("Survival Count")
# Out:
# Text(0.5, 1.0, 'Survival Count')

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    312
# Name: count, dtype: int64

# %%
#A countplot in Python is used to display the count (frequency) of observations in each category of a categorical variable.
sns.countplot(x="Sex",data=df)
plt.title("Distribution of passengers w.r.t Gender")
# Out:
# Text(0.5, 1.0, 'Distribution of passengers w.r.t Gender')

# %%
#Surivival rate Across Gender
df.groupby("Sex",as_index=True)["Survived"].value_counts()
# Out:
# /tmp/ipykernel_2614/948036450.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Sex",as_index=True)["Survived"].value_counts()
# Sex     Survived
# female  1           231
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
sns.countplot(x="Sex",hue="Survived",data=df)
plt.title("Survival Rate across Gender")
# Out:
# Text(0.5, 1.0, 'Survival Rate across Gender')

# %%
df["family"].unique()
# Out:
# array([ 1,  0,  4,  2,  6,  5,  3,  7, 10])

# %%
df.groupby("family",as_index=False)["Survived"].value_counts()
# Out:
#     family  Survived  count
# 0        0         0    374
# 1        0         1    161
# 2        1         1     89
# 3        1         0     72
# 4        2         1     59
# 5        2         0     43
# 6        3         1     21
# 7        3         0      8
# 8        4         0     12
# 9        4         1      3
# 10       5         0     19
# 11       5         1      3
# 12       6         0      8
# 13       6         1      4
# 14       7         0      6
# 15      10         0      7

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
#Survival rate of Gender who embarked with respective stations
embarked_survived=df[df["Survived"]==1].groupby(["Embarked"],as_index=False)["Survived"].size()
embarked_survived
# Out:
#   Embarked  size
# 0        C    93
# 1        Q    30
# 2        S   217

# %%
sns.barplot(x="Embarked",y="size",data=embarked_survived)
plt.title("embarked_survived")
# Out:
# Text(0.5, 1.0, 'embarked_survived')

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df.groupby(["Age"])["Survived"].mean()
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: Survived, Length: 88, dtype: float64

# %%
#Distribution of Age Who Travelled
sns.histplot(x="Age",data=df,kde=True,color=sns.color_palette("muted")[1])
plt.title("Distribution of Age who Travelled")
# Out:
# Text(0.5, 1.0, 'Distribution of Age who Travelled')

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked', 'family'],
#       dtype='object')

# %%
#Passengers Survived categorised according to their Pclass and Sex
passengers_survived=df[df["Survived"]==1].groupby(["Pclass","Sex"],as_index=False)["Survived"].value_counts()
passengers_survived
# Out:
# /tmp/ipykernel_2614/1534978902.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   passengers_survived=df[df["Survived"]==1].groupby(["Pclass","Sex"],as_index=False)["Survived"].value_counts()
#    Pclass     Sex  Survived  count
# 0       1  female         1     89
# 1       1    male         1     45
# 2       2  female         1     70
# 3       2    male         1     17
# 4       3  female         1     72
# 5       3    male         1     47

# %%
sns.barplot(data=passengers_survived,x="Pclass",y="count",hue="Sex")
plt.title("Passengers Survived according to their sex and Pclass")
# Out:
# Text(0.5, 1.0, 'Passengers Survived according to their sex and Pclass')

# %%
#Passengers Dead according to their Pclass and Sex
passengers_dead=df[df["Survived"]==0].groupby(["Pclass","Sex"],as_index=False)["Survived"].value_counts()
passengers_dead
# Out:
# /tmp/ipykernel_2614/200873574.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   passengers_dead=df[df["Survived"]==0].groupby(["Pclass","Sex"],as_index=False)["Survived"].value_counts()
#    Pclass     Sex  Survived  count
# 0       1  female         0      3
# 1       1    male         0     77
# 2       2  female         0      6
# 3       2    male         0     91
# 4       3  female         0     72
# 5       3    male         0    300

# %%
sns.barplot(data=passengers_survived,x="Pclass",y="count",hue="Sex")
plt.title("Passengers Dead according to their Pclass and Sex")
# Out:
# Text(0.5, 1.0, 'Passengers Dead according to their Pclass and Sex')

# %%
#mean fare spent on each class of pclass
passenger_fare=df.groupby(["Pclass"],as_index=False)["Fare"].mean()
passenger_fare
# Out:
#    Pclass       Fare
# 0       1  84.193516
# 1       2  20.662183
# 2       3  13.675550

# %%
sns.barplot(x="Pclass",y="Fare",data=passenger_fare)
plt.title("mean fare of each class of Pclass")
# Out:
# Text(0.5, 1.0, 'mean fare of each class of Pclass')

# %%
#survival_pclass_sexcount
survival_pclass_sexcount=df[df["Survived"]==1].groupby(["Pclass","Sex"],as_index=False)[["Survived"]].count()
survival_pclass_sexcount
# Out:
# /tmp/ipykernel_2614/3773851559.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_pclass_sexcount=df[df["Survived"]==1].groupby(["Pclass","Sex"],as_index=False)[["Survived"]].count()
#    Pclass     Sex  Survived
# 0       1  female        89
# 1       1    male        45
# 2       2  female        70
# 3       2    male        17
# 4       3  female        72
# 5       3    male        47

# %%
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=survival_pclass_sexcount)
plt.title("survival_pclass_sexcount")
# Out:
# Text(0.5, 1.0, 'survival_pclass_sexcount')

# %%
#death_pclass_sexcount
death_pclass_sexcount=df[df["Survived"]==0].groupby(["Pclass","Sex"],as_index=False)[["Survived"]].count()
death_pclass_sexcount.columns=["Pclass","Sex","Dead"]
death_pclass_sexcount
# Out:
# /tmp/ipykernel_2614/2015377629.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   death_pclass_sexcount=df[df["Survived"]==0].groupby(["Pclass","Sex"],as_index=False)[["Survived"]].count()
#    Pclass     Sex  Dead
# 0       1  female     3
# 1       1    male    77
# 2       2  female     6
# 3       2    male    91
# 4       3  female    72
# 5       3    male   300

# %%
sns.barplot(x="Sex",y="Dead",hue="Pclass",data=death_pclass_sexcount)
plt.title("death_pclass_sexcount")
# Out:
# Text(0.5, 1.0, 'death_pclass_sexcount')
